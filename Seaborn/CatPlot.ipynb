# %%
#cat plot==>Categorical Plot
import matplotlib.pyplot as plt
import seaborn as snc

data=snc.load_dataset('tips')
snc.catplot(data)
plt.show()

# %%
# To change the type of chart to bar chart
data=snc.load_dataset('tips')
snc.catplot(data,type='bar')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 3
#       1 # To change the type of chart to bar chart
#       2 data=snc.load_dataset('tips')
# ----> 3 snc.catplot(data,type='bar')
#       4 plt.show()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:2879, in catplot(data, x, y, hue, row, col, kind, estimator, errorbar, n_boot, seed, units, weights, order, hue_order, row_order, col_order, col_wrap, height, aspect, log_scale, native_scale, formatter, orient, color, palette, hue_norm, legend, legend_out, sharex, sharey, margin_titles, facet_kws, ci, **kwargs)
#    2876     if "s" not in plot_kws:
#    2877         plot_kws["s"] = plot_kws.pop("size", 5) ** 2
# -> 2879     p.plot_strips(
#    2880         jitter=jitter,
#    2881         dodge=dodge,
#    2882         color=color,
#    2883         plot_kws=plot_kws,
# ...
